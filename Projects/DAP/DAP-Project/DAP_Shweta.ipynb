# %%
#youtube
import requests
import json
from pymongo import MongoClient

client= MongoClient("mongodb+srv://dap:dap@cluster0.nddcd.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

db= client['Intercity_BusStop_Permit']
collection= db['Intercity_BusStop_Permit']

try:
    response_API= requests.get('https://data.cityofnewyork.us/resource/nmue-7zq2.json')
    data= response_API.text
    a=json.loads(data)
    b= collection.insert_many(a)
    
except:
    print("dataset cannot be loaded")

# %%
#https://www.geeksforgeeks.org/convert-pymongo-cursor-to-dataframe/
import pandas as pd
client= MongoClient("mongodb+srv://dap:dap@cluster0.nddcd.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

db = client['Intercity_BusStop_Permit']
collection= db['Intercity_BusStop_Permit']
cursor = db.Intercity_BusStop_Permit.find()
list_cur=list(cursor)
data= pd.DataFrame(list_cur)
data
# Out:
#                           _id   permitnumber applicationtrackingid  \
# 0    625edfdd20914a084cb8007a  QIB2018124A00      2018040300961620
# 1    625edfdd20914a084cb8007b     2015082074     ICBPS-20150820-74
# 2    625edfdd20914a084cb8007c  MIB2022073A18      2021102500886270
# 3    625edfdd20914a084cb8007d     2016100899     ICBPS-20161008-99
# 4    625edfdd20914a084cb8007e    20171015141    ICBPS-20171015-141
# ..                        ...            ...                   ...
# 995  625edfdd20914a084cb8045d  MIB2022047A23      2022020800623383
# 996  625edfdd20914a084cb8045e  MIB2022049A22      2022012400818603
# 997  625edfdd20914a084cb8045f  BIB2022043A04      2022011300762653
# 998  625edfdd20914a084cb80460  MIB2021052A01      2021011400527700
# 999  625edfdd20914a084cb80461  BIB2022043A02      2022011300721080
#
#     sequencenumber applicationtypeshortdesc permitstatusid  \
# 0             0001                      New            906
# ...

# %%
data.isnull().sum()
# Out:
# _id                         0
# permitnumber                0
# applicationtrackingid       0
# sequencenumber              0
# applicationtypeshortdesc    0
# permitstatusid              0
# permitstatusshortdesc       0
# permitseriesid              0
# permitseriesshortdesc       0
# permittypeid                0
# permittypedesc              0
# specificstipulations        0
# permitissuedate             0
# issuedworkstartdate         0
# issuedworkenddate           0
# boroughname                 0
# onstreetname                0
# fromstreetname              0
# tostreetname                0
# permitteename               0
# createdon                   0
# modifiedon                  0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _id                       1000 non-null   object
#  1   permitnumber              1000 non-null   object
#  2   applicationtrackingid     1000 non-null   object
#  3   sequencenumber            1000 non-null   object
#  4   applicationtypeshortdesc  1000 non-null   object
#  5   permitstatusid            1000 non-null   object
#  6   permitstatusshortdesc     1000 non-null   object
#  7   permitseriesid            1000 non-null   object
#  8   permitseriesshortdesc     1000 non-null   object
#  9   permittypeid              1000 non-null   object
#  10  permittypedesc            1000 non-null   object
#  11  specificstipulations      1000 non-null   object
#  12  permitissuedate           1000 non-null   object
# ...

# %%
data.drop(columns=['_id'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   permitnumber              1000 non-null   object
#  1   applicationtrackingid     1000 non-null   object
#  2   sequencenumber            1000 non-null   object
#  3   applicationtypeshortdesc  1000 non-null   object
#  4   permitstatusid            1000 non-null   object
#  5   permitstatusshortdesc     1000 non-null   object
#  6   permitseriesid            1000 non-null   object
#  7   permitseriesshortdesc     1000 non-null   object
#  8   permittypeid              1000 non-null   object
#  9   permittypedesc            1000 non-null   object
#  10  specificstipulations      1000 non-null   object
#  11  permitissuedate           1000 non-null   object
#  12  issuedworkstartdate       1000 non-null   object
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data.drop_duplicates()
# Out:
#       permitnumber applicationtrackingid sequencenumber  \
# 0    QIB2018124A00      2018040300961620           0001
# 1       2015082074     ICBPS-20150820-74           0001
# 2    MIB2022073A18      2021102500886270           0001
# 3       2016100899     ICBPS-20161008-99           0001
# 4      20171015141    ICBPS-20171015-141           0001
# ..             ...                   ...            ...
# 995  MIB2022047A23      2022020800623383           0001
# 996  MIB2022049A22      2022012400818603           0001
# 997  BIB2022043A04      2022011300762653           0001
# 998  MIB2021052A01      2021011400527700           0001
# 999  BIB2022043A02      2022011300721080           0001
#
#     applicationtypeshortdesc permitstatusid permitstatusshortdesc  \
# 0                        New            906    VOIDED AFTER ISSUE
# 1                      Renew            030               EXPIRED
# 2                        New            006      ISSUED & PRINTED
# ...

# %%
import psycopg2
conn= psycopg2.connect(dbname='postgres',user='postgres',password='password',host='localhost')
print(conn)
conn.autocommit=True
# Out:
# <connection object at 0x0000028C73F5DBF0; dsn: 'user=postgres password=xxx dbname=postgres host=localhost', closed: 0>

# %%
import sqlalchemy as sqla
engine=sqla.create_engine('postgresql://postgres:password@localhost:5432/postgres')
con_engine=engine.connect()

# %%
data.to_sql('Intercity_Bus_Stop',con_engine, if_exists='replace',index=False)

# %%
print(engine.table_names())
# Out:
# ['Intercity_Bus_Stop', 'Intercity_BusStop_Permit', 'Intercity_BusStop']
# C:\Users\shwet\AppData\Local\Temp/ipykernel_4092/1043810782.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %%
Intercity_Bus_Stop_Data=pd.read_sql_table("Intercity_Bus_Stop",con_engine)

# %%
Intercity_Bus_Stop_Data.shape
# Out:
# (1000, 21)

# %%
Intercity_Bus_Stop_Data.describe()
# Out:
#          permitnumber applicationtrackingid sequencenumber  \
# count            1000                  1000           1000
# unique           1000                  1000              1
# top     QIB2018124A00      2018040300961620           0001
# freq                1                     1           1000
#
#        applicationtypeshortdesc permitstatusid permitstatusshortdesc  \
# count                      1000           1000                  1000
# unique                        2              3                     3
# top                         New            030               EXPIRED
# freq                        574            726                   726
#
#        permitseriesid permitseriesshortdesc permittypeid  \
# count            1000                  1000         1000
# unique              1                     2            1
# top                IB       Bus Stop Permit         IB01
# freq             1000                   767         1000
#
# ...

# %%
import matplotlib.pyplot as plt
Intercity_Bus_Stop_Data['applicationtypeshortdesc'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
Intercity_Bus_Stop_Data['boroughname'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
applicationtype = Intercity_Bus_Stop_Data.applicationtypeshortdesc.value_counts()
plt.figure(figsize=(12,8))
sns.barplot(applicationtype.index, applicationtype.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Run type', fontsize=12)
plt.title('Count of rows in each dataset (run_type)', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\shwet\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
plt.style.use('ggplot')
x = Intercity_Bus_Stop_Data['applicationtypeshortdesc']
g = Intercity_Bus_Stop_Data['boroughname']
plt.bar(x, g, color='#7ed6df')
plt.show()

# %%
us=Intercity_Bus_Stop_Data[Intercity_Bus_Stop_Data.applicationtypeshortdesc=="New"]
us
# Out:
#       permitnumber applicationtrackingid sequencenumber  \
# 0    QIB2018124A00      2018040300961620           0001
# 2    MIB2022073A18      2021102500886270           0001
# 8    BIB2020007A00      2019112600704847           0001
# 10      2017041751     ICBPS-20170417-51           0001
# 11      2015032336     ICBPS-20150323-36           0001
# ..             ...                   ...            ...
# 974  MIB2022047A29      2022020800534526           0001
# 975  MIB2022042A00      2020022900061470           0001
# 977  MIB2022047A09      2022020900418820           0001
# 989  MIB2022047A01      2022020900571093           0001
# 995  MIB2022047A23      2022020800623383           0001
#
#     applicationtypeshortdesc permitstatusid permitstatusshortdesc  \
# 0                        New            906    VOIDED AFTER ISSUE
# 2                        New            006      ISSUED & PRINTED
# 8                        New            006      ISSUED & PRINTED
# ...

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.stripplot(Intercity_Bus_Stop_Data['applicationtypeshortdesc'],Intercity_Bus_Stop_Data['boroughname'])
# Out:
# C:\Users\shwet\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='applicationtypeshortdesc', ylabel='boroughname'>

# %%
us=(Intercity_Bus_Stop_Data['applicationtypeshortdesc'],Intercity_Bus_Stop_Data['boroughname'])
us
# Out:
# (0        New
#  1      Renew
#  2        New
#  3      Renew
#  4      Renew
#         ...
#  995      New
#  996    Renew
#  997    Renew
#  998    Renew
#  999    Renew
#  Name: applicationtypeshortdesc, Length: 1000, dtype: object,
#  0         QUEENS
#  1      MANHATTAN
#  2      MANHATTAN
#  3       BROOKLYN
#  4      MANHATTAN
#           ...
#  995    MANHATTAN
#  996    MANHATTAN
#  997     BROOKLYN
#  998    MANHATTAN
#  999     BROOKLYN
#  Name: boroughname, Length: 1000, dtype: object)

# %%
Intercity_Bus_Stop_Data.head()
# Out:
#     permitnumber applicationtrackingid sequencenumber  \
# 0  QIB2018124A00      2018040300961620           0001
# 1     2015082074     ICBPS-20150820-74           0001
# 2  MIB2022073A18      2021102500886270           0001
# 3     2016100899     ICBPS-20161008-99           0001
# 4    20171015141    ICBPS-20171015-141           0001
#
#   applicationtypeshortdesc permitstatusid permitstatusshortdesc  \
# 0                      New            906    VOIDED AFTER ISSUE
# 1                    Renew            030               EXPIRED
# 2                      New            006      ISSUED & PRINTED
# 3                    Renew            030               EXPIRED
# 4                    Renew            030               EXPIRED
#
#   permitseriesid permitseriesshortdesc permittypeid  \
# 0             IB              Bus Stop         IB01
# 1             IB              Bus Stop         IB01
# 2             IB       Bus Stop Permit         IB01
# ...

# %%
data = Intercity_Bus_Stop_Data['boroughname'].value_counts().sort_index()
data.head()

#sns.heatmap(Intercity_Bus_Stop_Data.corr())
# Out:
# BRONX              3
# BROOKLYN         109
# MANHATTAN        826
# QUEENS            61
# STATEN ISLAND      1
# Name: boroughname, dtype: int64

# %%
ax = sns.countplot(x="boroughname", hue="applicationtypeshortdesc", data=Intercity_Bus_Stop_Data)

# %%
def plotHistogram(df, nHistogramShown, nHistogramPerRow):
nunique = df.nunique()
df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
nRow, nCol = df.shape
columnNames = list(df)
nHistRow = (nCol + nHistogramPerRow - 1) / nHistogramPerRow
plt.figure(num=None, figsize=(6*nHistogramPerRow, 8*nHistRow), dpi=80, facecolor='w', edgecolor='k')
for i in range(min(nCol, nHistogramShown)):
plt.subplot(nHistRow, nHistogramPerRow, i+1)
df.iloc[:,i].hist()
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.title(f'{columnNames[i]} (column {i})')
plt.tight_layout(pad=1.0, w_pad=1.0, h_pad=1.0)
plt.show()
# Out:
#   File "C:\Users\shwet\AppData\Local\Temp/ipykernel_4092/998699845.py", line 2
#     nunique = df.nunique()
#     ^
# IndentationError: expected an indented block
