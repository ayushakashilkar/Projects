# %%
#connecting to mongo db and loading dataset by retrieving from API
import requests
import json
from pymongo import MongoClient

client= MongoClient("mongodb+srv://dap:dap@cluster0.nddcd.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

db= client['Census_2010_2020']
collection= db['Census_2010_2020']

try:
    response_API= requests.get('https://data.ny.gov/resource/sxhg-qquj.json')
    data= response_API.text
    a=json.loads(data)
    b= collection.insert_many(a)
    
except:
    print("dataset cannot be loaded")

# %%
#Retrive data from mognodb to dataframe
import pandas as pd
myclient = MongoClient("mongodb+srv://dap:dap@cluster0.nddcd.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
database = myclient['Census_2010_2020']
collection = database['Census_2010_2020']
dataset = pd.DataFrame(list(collection.find()))
dataset
# Out:
#                           _id area_type        area_name  \
# 0    62644343f953c1e2d56ce7b1     State   New York State
# 1    62644343f953c1e2d56ce7b2    County    Albany County
# 2    62644343f953c1e2d56ce7b3    County  Allegany County
# 3    62644343f953c1e2d56ce7b4    County     Bronx County
# 4    62644343f953c1e2d56ce7b5    County    Broome County
# ..                        ...       ...              ...
# 995  62644343f953c1e2d56ceb94      Town   Annsville town
# 996  62644343f953c1e2d56ceb95      Town        Pike town
# 997  62644343f953c1e2d56ceb96      Town      Orange town
# 998  62644343f953c1e2d56ceb97      Town  Smithfield town
# 999  62644343f953c1e2d56ceb98      Town    Rockland town
#
#     _2010_census_population _2020_census_population population_change  \
# 0                  19378102                20201249            823147
# 1                    304204                  314848             10644
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _id                        1000 non-null   object
#  1   area_type                  1000 non-null   object
#  2   area_name                  1000 non-null   object
#  3   _2010_census_population    999 non-null    object
#  4   _2020_census_population    1000 non-null   object
#  5   population_change          999 non-null    object
#  6   population_percent_change  999 non-null    object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %%
dataset.isnull().sum()
# Out:
# _id                          0
# area_type                    0
# area_name                    0
# _2010_census_population      1
# _2020_census_population      0
# population_change            1
# population_percent_change    1
# dtype: int64

# %%
dataset.dropna(how='any',inplace=True)
dataset.isnull().sum()
# Out:
# _id                          0
# area_type                    0
# area_name                    0
# _2010_census_population      0
# _2020_census_population      0
# population_change            0
# population_percent_change    0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _id                        999 non-null    object
#  1   area_type                  999 non-null    object
#  2   area_name                  999 non-null    object
#  3   _2010_census_population    999 non-null    object
#  4   _2020_census_population    999 non-null    object
#  5   population_change          999 non-null    object
#  6   population_percent_change  999 non-null    object
# dtypes: object(7)
# memory usage: 62.4+ KB

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 999, dtype: bool

# %%
dataset.drop_duplicates()
# Out:
#                           _id area_type        area_name  \
# 0    62644343f953c1e2d56ce7b1     State   New York State
# 1    62644343f953c1e2d56ce7b2    County    Albany County
# 2    62644343f953c1e2d56ce7b3    County  Allegany County
# 3    62644343f953c1e2d56ce7b4    County     Bronx County
# 4    62644343f953c1e2d56ce7b5    County    Broome County
# ..                        ...       ...              ...
# 995  62644343f953c1e2d56ceb94      Town   Annsville town
# 996  62644343f953c1e2d56ceb95      Town        Pike town
# 997  62644343f953c1e2d56ceb96      Town      Orange town
# 998  62644343f953c1e2d56ceb97      Town  Smithfield town
# 999  62644343f953c1e2d56ceb98      Town    Rockland town
#
#     _2010_census_population _2020_census_population population_change  \
# 0                  19378102                20201249            823147
# 1                    304204                  314848             10644
# ...

# %%
import psycopg2
conn= psycopg2.connect(dbname='postgres',user='postgres',password='password',host='localhost')
print(conn)
conn.autocommit=True
# Out:
# <connection object at 0x00000215FD21CD00; dsn: 'user=postgres password=xxx dbname=postgres host=localhost', closed: 0>

# %%
import sqlalchemy as sqla
engine=sqla.create_engine('postgresql://postgres:password@localhost:5432/postgres')
con_engine=engine.connect()

# %%
dataset.to_sql('Census_',con_engine, if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1266         for args in page:
# ...
